# %%
import pandas as pd

# %%
df = pd.read_csv('./input/export_example_010614_090210.csv', dtype={'CW_HSCODE': str})

# %%
df.head()
# Out:
#                         _id CW_HSCODE  \
# 0  670d21ea631a82b8a8a3089e    090210
# 1  670d21ea631a82b8a8a3089f    090210
# 2  670d21ea631a82b8a8a308a0    090210
# 3  670d21ea631a82b8a8a308a1    090210
# 4  670d21ea631a82b8a8a308a2    090210
#
#                                       url_for_verify  \
# 0  https://www.customs.go.jp/toukei/srch/indexe.h...
# 1  https://www.customs.go.jp/toukei/srch/indexe.h...
# 2  https://www.customs.go.jp/toukei/srch/indexe.h...
# 3  https://www.customs.go.jp/toukei/srch/indexe.h...
# 4  https://www.customs.go.jp/toukei/srch/indexe.h...
#
#                  foreign_id              mark               COUNTRY UNIT1  \
# 0  67092f6ee303cd06213c553e  Result of Search      (100 TOKYO)TOTAL
# 1  67092f6ee303cd06213c553e  Result of Search  (0902.10-100  )TOTAL
# 2  67092f6ee303cd06213c553e  Result of Search             105 CHINA
# 3  67092f6ee303cd06213c553e  Result of Search            106 TAIWAN
# ...

# %% [markdown]
# [数据样例](./input/exec)
